# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
from time import sleep, strftime
import pandas as pd
import numpy as np
import datetime as dt
import os

#import urllib
from bs4 import BeautifulSoup

log = True
herstarten = True

pad = 'J:\\Data Science\\Data\\web\\'

#import requests
#import re
#https://realpython.com/python-web-scraping-practical-introduction/
#https://www.dataquest.io/blog/web-scraping-tutorial-python/

#status 0: geen fouten gevonden
#status 1: niet in de doelgroep (BAS, SBAS)
#status 2: niet geldig op de peidatum
#status 3: ongeldige url (syntax)
#status 4: ongeldige url (site niet gevonden)


#todo:
#   doc-documenten als zodanig opslaan
#   pdf's met 0kB bekijken'
#   05HC geeft nog: KeyError: 'content-type'
#   lijsten als input:
#      onderwerpen
#      zoektermen (inclusief de volgorde)
#      aantal pagina's scannen per brin
#      selectiecriteria organisaties

# %%
def url_beautify(url):
    url = url.strip()
    if url[:7] != 'http://' and url[:8] != 'https://':
        url = 'http://' + url
    return url
    
def url_controle_syntax(df):
    ok = []
    if log:
        url_fouten = open('c:\\temp\\urls_met_foute_syntax.csv', 'w')
        url_fouten.write('CODE_FUNCTIE;CODE_SOORT;NR_ADMINISTRATIE;fout;url\n')
    for index, regel in df.iterrows():
        url2 = url_beautify(regel['URL'])
        url3 = url2[url2.find("//")+2:]
        fout = ''
        for teken in ',ë:~\\@':
            if fout == '' and teken in url3:
                fout = 'url bevat een "' + teken + '"'
        if fout != '' and log and regel['status'] == 0 :
            #print(url3, ' ', regel['status'], fout)
            url_fouten.write(regel['CODE_FUNCTIE'] + ';' + regel['CODE_SOORT'] + \
                ';' + regel['NR_ADMINISTRATIE'] + ';' + fout + ';' + url3 + '\n')
        ok += [fout != '']
    if log:
        url_fouten.close()
    return ok

# geeft de zichtbare tekst van een anchor terug: <a hre...>tekst</a>
def anchor_tekst(tekst):
    t, s = '', 0
    for x in str(tekst):
        if x == '<':
            s += 1
        elif x == '>':
            s -= 1
        elif s == 0:
            t += x
    return t.lower().strip()

# geeft de volledige url van een anchor terug
def anchor_url(tekst, url):
        # tekst is de anchor
        # url is de url van de pagina waarop de link is gevonden
    b, href = False, ''
    for x in tekst.replace(' ','"').split('"'):
        if b == True:                                  #vorige woord was 'href'
            href = x
            b = False
        elif x == 'href=':
            b = True
    if href == '':                                        # geen href in anchor
        return ''
    elif href[:4] == 'http':     #absolute link, kan direct teruggegeven worden
        return href
    url_root = url[:10 + (url + '/')[10:].find('/')]                 #bepaal root
    if href == '/':                                   #verwijzing naar zichzelf
        return url_root
    elif href[0] == '/':          #tekst begint met een slash (sub van de root)
        if url[-1] == '/':
           return url_root + href
        else:
           return url_root + href
    else:                                           #relatieve link in map zelf
        if url[-1:] == '/':
            url_root = url[:-1]
        else:
            url_root = url
        #return url_root[:url_root.rfind('/')] + '/' + href
        return url_root + '/' + href
#print(anchor_url('<a href="bla1.nl">bla2</a>', 'http://bol.com/bla3/bla4/'))
#print(anchor_url('<a href="/">bla2</a>', 'http://www.duo.nl'))

#def link volgen(NR_ADMINISTRATIE, diepte)

# %%
def nu():
    return strftime("%H:%M:%S")
#    return str(dt.datetime.now().hour) + ":" + str(dt.datetime.now().minute) \
#        + ":" + str(dt.datetime.now().second)
# print(nu())

# %%
def simple_get(url):
    try:
        with closing(get(url)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None
    except RequestException as e:
        return None
def is_good_response(resp):
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)

# %%
# laad of herlaad de lijst met urls.
if herstarten:
    print('maak urllijst')
    df = pd.read_csv('J:\\Data Science\\Data\\Brin\\org_url\\org_url_20180904.txt', sep='\t' )
    df['DT_EINDE_RECORD'].fillna(21001231, inplace = True)
    df['DT_EINDE_RECORD'] = df['DT_EINDE_RECORD'].astype('int64', inplace = True)
    df['status'] = 0
    df['status_dat'] = dt.datetime.now()
    df.to_csv(pad + 'urllijst.csv', sep='\t', encoding='utf-8', index=False)
else:
    print('laad urllijst')
    df = pd.read_csv(pad + 'urllijst.csv', sep='\t', encoding='utf-8')
    
print(df.loc[df['status'] == 0].shape)
# , encoding='utf-8'
# Out:
# maak urllijst
# (49749, 8)

# %%
# bekijk enkel de url's met een geldige syntax:
controle = url_controle_syntax(df)
df.loc[controle, ['status', 'status_dat']] = [3, dt.datetime.now()]
print(df.loc[df['status'] == 0].shape)
df.to_csv(pad + 'urllijst.csv', sep='\t', encoding='utf-8', index=False)
# Out:
# (49749, 8)

# %%
# bekijk enkel url's geldig op de prikdatum:
prikdatum = 20181001
df.loc[(df.DT_BEGIN_RECORD > prikdatum) | (prikdatum > df.DT_EINDE_RECORD), ['status', 'status_dat']] = [2, dt.datetime.now()]
print(df.loc[df['status'] == 0].shape)
# Out:
# (17484, 8)

# %%
# selectie bij het scannen:

# bekijk enkel de basisscholen:
if False:
    df.loc[df['CODE_SOORT'] != 'BAS', ['status', 'status_dat']] = [1, dt.datetime.now()]

# of enkel alle brin4's
#df.loc[df['CODE_FUNCTIE'] != 'U', ['status', 'status_dat']] = [1, dt.datetime.now()]

print(df.loc[df['status'] == 0].shape)
# Out:
# (17484, 8)

# %%
df["status"].value_counts()
# Out:
# 2    32265
# 0    17484
# Name: status, dtype: int64

# %%
########################################
print('laad urllijst')
df = pd.read_csv(pad + 'urllijst.csv', sep='\t', encoding='utf-8')
df.loc[df['status'] == 0].sort_values(by='NR_ADMINISTRATIE').head()
# Out:
# laad urllijst
#      NR_ADMINISTRATIE  DT_BEGIN_RECORD  DT_EINDE_RECORD CODE_FUNCTIE  \
# 1314            00008         20100420         20120807            B
# 1315            00008         19760101         20100420            B
# 1316            00008         20120807         21001231            B
# 1317            00009         20100420         20121101            B
# 1318            00009         20121101         21001231            B
#
#      CODE_SOORT         URL  status                  status_dat
# 1314       BINS  www.rug.nl       0  2018-10-05 13:32:57.453003
# 1315       BINS  www.rug.nl       0  2018-10-05 13:32:57.453003
# 1316       BINS  www.rug.nl       0  2018-10-05 13:32:57.453003
# 1317       BINS   www.uu.nl       0  2018-10-05 13:32:57.453003
# 1318       BINS   www.uu.nl       0  2018-10-05 13:32:57.453003

# %%
def anchor_verwerken(instelling, anchor, url_vorig, diepte, themas):
        # input: instelling: BRIN
        # input: anchor: de volledig gevonden hyperlink
        # input: url_vorig: pagina vanuitwaar dehyperlink wordt aangeroepen (ivm relatieve links)
        # input: diepte: nivo van recusie
        # input: docsoorten: bijvoorbeeld ['schoolgids', 'jaarverslag']
        # rv: document dat gevonden is met soort en jaar
        # rv: lijst met url's om ook de te werken
    return [succes, ['schoolgids_2017', 'jaarverslag 2016']]

def document_opslaan(NR_ADMINISTRATIE, soort, url):
    jaren = bepaal_jaren(url)
    for jaar in jaren:
        print('Sla', soort, '-document op in', pad, '/', str(jaar), '/', NR_ADMINISTRATIE)

# %%
def zoeklijst_uitbreiden(lijst, tekst, url):
#    print(92, tekst)
#    if 'oo' not in tekst:                        #tijdelijke beperking van urls
#        return
    if tekst == '':                          #bedenk een label als dit nodig is
    #if tekst in ('', '/'):                  #bedenk een label als dit nodig is
        t = url[url.replace('//','__').find('/'):]
    else:
        t = tekst.lower()
#    print(93, t)
    u = url.split("#")[0]
    if t in lijst.keys():                             #schermtekst komt al voor
        if not u in lijst[t]:                                #maar url nog niet
            lijst[t] += [u]
    else:                                       #schermtekst komt nog niet voor
        lijst[t] = [u]

# %%
        #zoeklijst = {'start': ['http://www.hetsterrenlicht.nl/School/Schoolgids']}
#        while len(zoeklijst) > 0 and todo != [] and zoek_n > 0: #scan zoeklijst
#            print('zoeklijst:', zoeklijst)
#            print('gedaan:', gedaan)
#                print("deze url al gedaan")
#                print(96, zoek_n)
#                print(99, zoek_n, len(str(pagina)))
#                    print(95, anchor)
#                        print(98)
#                    print(72, anchor.contents)
#                    print(94, len(zoeklijst), url_totaal)
#            print('------', zoek_n, len(zoeklijst), len(gedaan))

# %%
def bedenk_naam(url, org, onderwerp, tekst):
    if   '2010' in url or '1011' in url or '10-11' in url or '2010' in tekst:
        j = '2015'
    elif '2011' in url or '1112' in url or '11-12' in url or '2011' in tekst:
        j = '2015'
    elif '2012' in url or '1213' in url or '12-13' in url or '2012' in tekst:
        j = '2015'
    elif '2013' in url or '1314' in url or '13-14' in url or '2013' in tekst:
        j = '2015'
    elif '2014' in url or '1415' in url or '14-15' in url or '2014' in tekst:
        j = '2015'
    elif '2015' in url or '1516' in url or '15-16' in url or '2015' in tekst:
        j = '2015'
    elif '2016' in url or '1617' in url or '16-17' in url or '2016' in tekst:
        j = '2016'
    elif '2017' in url or '1718' in url or '17-18' in url or '2017' in tekst:
        j = '2017'
    elif '2018' in url or '1819' in url or '18-19' in url or '2018' in tekst:
        j = '2018'
    elif '2019' in url or '1920' in url or '19-20' in url or '2019' in tekst:
        j = '2019'
    else:
        j = '0000'
        print('pas de functie bedenk_naam aan omdat geen jaar bepaald kon worden')
    naam = onderwerp + '_' + j  + '_' + org
    url2 = url.split("?")[0].lower()           #verwijder tekst naar vraagteken
    if url2.endswith(('.pdf')):
        return naam + '.pdf'
    elif url2.endswith(('.doc')):
        return naam + '.doc'
    elif url2.endswith(('.docx')):
        return naam + '.docx'
    else:
        print(132, 'onbekend type')
        print(133, url)
        print(133, url2)
        print(134, tekst)
        q = 1 / 0
        return naam + '.onbekend'
#print(bedenk_naam("http:\\bla_2015-2019", '00AH', 'jaarverslag', 'bla'))

# %%
def document_downloaden(u_link, NR_ADMINISTRATIE, soort, u_tekst):
    naam = bedenk_naam(u_link, NR_ADMINISTRATIE, todo_i, u_tekst)
    print('downloaden:', naam, 'u_link')
    with open('c://temp//' + naam, 'wb') as f:
        f.write(get(u_link).content)

# %%
# kies uit de zoeklijst de meest waarschijnlijke url
def url_kiezen(d):
    #lijst met termen in aflopen prioriteit:
    zoektermen = ['schoolgids', 'schooldocumenten', 'download', 'download schoolgids', 'downloads',  \
        'organisatie', 'documenten', 'schoolplan', 'onze school', 'documentatie', 'school',  \
        'jaargids', 'jaarverslag', 'informatie', 'informatiekaart',           \
        'voor ouders', 'jaarplanning', 'informatiegids', 'organisatie']
    # bij 1 element stuur kies de eerste
    if len(d) == 1:
        return (list(d.keys())[0], d[list(d.keys())[0]][0])
    
    for w in zoektermen:                              #doorloop alle zoektermen
        
        # zoek naar PDF's in urls
        for k in d.keys():                                        #loop teksten
            for u in d[k]:                            #loop urls van elke tekst
                if u.endswith(tuple([".pdf", ".pdf?"])):
                    if u.find(w) > -1:            #als zoekterm voorkomt in url
                        return (k, u)
        
        # zoekterm gelijk aan complete tekst
        for k in d.keys():                                        #loop teksten
            if k.find(w) > -1:                  #als zoekterm voorkomt in tekst
                return [k, d[k][0]]
        
        # zoekterm gelijk aan deel tekst
        for k in d.keys():                                        #loop teksten
            if u.find(w) > -1:                    #als zoekterm voorkomt in url
                return (k, u)

        # deel zoekterm gelijk aan tekst
        for k in d.keys():                                        #loop teksten
            if w.find(k) > -1:                    #als zoekterm voorkomt in url
                return (k, u)

    # kies de eerste (oudste) link van de eerste term
    return (list(d.keys())[0], d[list(d.keys())[0]][0])

# %%
# een paar scholen negeren omdat deze nog fouten opleveren
if True:
    df.loc[df['NR_ADMINISTRATIE'].isin(['00BW', '00EI', '00ML',
        '00KM40', '00ML00', '00MP', '00MV',
        '02RM', '03HH', '03IC', '03LR', '04JR', '04KC', 
        '04MZ', '04VG', '04VG00', '04VH', '05IL00', '05TN',
        '05TN00', '05RV', '05ZW', '06NI', '08JE00', '08NF', '08NP', '09LK', '09LK00', '10JM',
        '10JT', '10NH', '10NL', '10PO', '10QE', '10QY', '10UF', '10UF00',
        '11UH00', '12BF00', '12CL00', '12GN00', '12ZL ', '15SZ', '15TL', '13OW00', 
        '13OW01', '13WM', '13WM00', '14RC', '15VQ00', 
        '16JK', '16JK00', '17NQ', '17NQ00', '17OB01', 
        '17OF', '17OF00', '17PB', '17PB00', '17QF', '17QF00', '18SP', '19QL', '20AA', '21HC12',
        '23DJ', '23DR', '23RC00', '25KE', '25KE00', '26AW', 
        '26AW00', '29XL', '30837', '30BE', '30UF', '30UN', '31028', '31FM', '31FM00',
        '35647', '40180', '40945', '41407', '41490', '41509',
        '41812', '42616', 'VO2810', 'VO2307']), 'status'] = 8

# %%
# scan de sites ####################################################
for index, regel in df.sample(frac=1).iterrows():
#for index, regel in df[18903:97022:11].iterrows(): 
    if regel['status'] == 0:
        print(nu(), 'instelling: ', regel['NR_ADMINISTRATIE'], index)
        zoeklijst = {'start': [url_beautify(regel['URL'])]}    #nog te bekijken
        gedaan = []
        todo = ['informatiegids', 'jaarkalender', 'jaarplan', 'jaarrekening', 
            'jaarverslag', 'schoolinformatieboekje', 'schoolgids',
            'schoolplan', 'schoolondersteuningsprofiel']
        zoek_n = 30                    # zo vaak per brin zoeken naar goede url
        while len(zoeklijst) > 0 and zoek_n > 0:                #scan zoeklijst
            u_tekst, u_link = url_kiezen(zoeklijst)
            if u_link in gedaan:                                #link al gedaan
                if len(zoeklijst[u_tekst]) == 1:      #enige link van een tekst
                    del zoeklijst[u_tekst]  #verwijder u_tekst uit de zoeklijst
                else:
                    zoeklijst[u_tekst] = zoeklijst[u_tekst][1:]   #verw 1e link
                continue
            print(' -', zoek_n, len(zoeklijst), len(gedaan), 'Gekozen url:', u_link, '"' + u_tekst + '"')
            if u_link.split("?")[0].lower().endswith(('.pdf', '.doc', '.docx', '.txt')):
                for todo_i in todo:
                    if todo_i in u_link.lower() or todo_i in u_tekst:
                        document_downloaden(u_link, regel['NR_ADMINISTRATIE'], todo_i, u_tekst)
            else:                                                 #volg de link
                try:
                    pagina = simple_get(u_link)
                except KeyError:
                    pass
                soup = BeautifulSoup(str(pagina),'html.parser')
                for anchor in soup.find_all('a'):
                    if str(anchor).find('href') < 0:
                        continue
                    if anchor.contents == []:
                        tekst = ''
                    else:
                        tekst = str(anchor.contents[0])
                    url_totaal = anchor_url(str(anchor), u_link)
                    zoeklijst_uitbreiden(zoeklijst, tekst, url_totaal)
            gedaan += [u_link]
            zoek_n -= 1
            sleep(1.12)
        #print('einde organisatie:', regel['NR_ADMINISTRATIE'], len(zoeklijst))
# Out:
# 14:10:27 instelling:  11GC 17020
#  - 30 1 0 Gekozen url: http://www.villa60.nl "start"
#  - 29 61 1 Gekozen url: https://villa60.poolsterscholen.nl/Onze-school/Schoolgids "<span class="rmtext">schoolgids</span>"
#  - 28 76 2 Gekozen url: https://villa60.poolsterscholen.nl/Portals/104/docs/Schoolgids/Schoolgids%202018-2019%20Villa60%20deel%203.pdf?ver=2018-09-17-161159-960 "documenten"
# downloaden: schoolgids_2018_11GC.pdf u_link
#  - 27 75 3 Gekozen url: http://www.schoolwebsite.nu/Functionaliteiten/Schoolwebsite-App "download "
#  - 26 124 4 Gekozen url: https://www.schoolwapps.nl/over-schoolwapps/downloads "downloads"
#  - 25 136 5 Gekozen url: https://files.heutink-ict.nl/schoolwapps/poster-schoolwapps.pdf "download de poster (a3)"
#  - 24 135 6 Gekozen url: https://villa60.poolsterscholen.nl/Onze-school/Documenten "<span class="rmtext">documenten</span>"
#  - 23 145 7 Gekozen url: https://villa60.poolsterscholen.nl/Portals/104/docs/Schoolgids/Schoolgids%202017-2018%20Villa60%20deel%201.pdf?ver=2017-09-15-095816-447 "schoolgids deel 1"
# downloaden: schoolgids_2017_11GC.pdf u_link
#  - 22 144 8 Gekozen url: https://villa60.poolsterscholen.nl/Portals/104/docs/Schoolgids/Schoolgids%202017-2018%20Villa60%20deel%202.pdf?ver=2017-09-15-095816-557 "schoolgids deel 2"
# downloaden: schoolgids_2017_11GC.pdf u_link
#  - 21 143 9 Gekozen url: https://villa60.poolsterscholen.nl/Portals/104/docs/Schoolgids/Schoolgids%202017-2018%20Villa60%20deel%203.pdf?ver=2017-09-15-095816-663 "schoolgids deel 3"
# downloaden: schoolgids_2017_11GC.pdf u_link
#  - 20 137 10 Gekozen url: https://villa60.poolsterscholen.nl/Onze-

# pas de functie bedenk_naam aan omdat geen jaar bepaald kon worden
# downloaden: schoolgids_0000_19ZX.pdf u_link
#  - 27 97 3 Gekozen url: http://www.huygens.nl/over-huygens/schoolleiding/ "schoolleiding"
#  - 26 96 4 Gekozen url: http://www.huygens.nl/ouders/schoolvakanties/ "schoolvakanties"
#  - 25 96 5 Gekozen url: http://www.huygens.nl/ouders/schoolkosten/ "schoolkosten"
#  - 24 98 6 Gekozen url: http://www.huygens.nl/leerlingen/schoolregels/ "schoolregels"
#  - 23 97 7 Gekozen url: http://www.huygens.nl/groep-8/informatieavond-ouders-groep-8/ "informatieavond ouders groep 8"
#  - 22 98 8 Gekozen url: https://www.huygens.nl/media/org/2ebbd6c27b52cfe57b62f534e8e4895e.pdf "ouders"
#  - 21 96 9 Gekozen url: http://www.huygens.nl/home/ "home"
#  - 20 97 10 Gekozen url: http://www.huygens.nl/ouders/ "ouders"
#  - 19 108 11 Gekozen url: http://www.huygens.nl/ouders/schoolkosten/schoolkosten "home"
# 14:12:54 instelling:  26PY00 37621
#  - 30 1 0 Gekozen url: http://www.kbsdevlieger.nl "start"
#  - 29 4 1 Gekozen url: http://www.kbsdevlieger1.nl/ "<img alt="" height="200" src="images/devlieger1.png" width="200"/>"
#  - 28 61 2 Gekozen url: http://www.kbsdevlieger1.nl/files/schoolgids.pdf "download onze schoolgids "
# pas de functie bedenk_naam aan omdat geen jaar bepaald kon worden
# downloaden: schoolgids_0000_26PY00.pdf u_link
#  - 27 60 3 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html "downloads"
#  - 26 71 4 Gekozen url: http://www.kbsdevlieger1.nl/files/schoolgids_bijlage.pdf "bijlage"
# pas de functie bedenk_naam aan omdat geen jaar bepaald kon worden
# downloaden: schoolgids_0000_26PY00.pdf u_link
#  - 25 69 5 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 24 72 6 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 23 73 7 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 22 74 8 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 21 75 9 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 20 76 10 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 19 77 11 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 18 78 12 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 17 79 13 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 16 80 14 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 15 81 15 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 14 82 16 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 13 83 17 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 12 84 18 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 11 85 19 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 10 86 20 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 9 87 21 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 8 88 22 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 7 89 23 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 6 90 24 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 5 91 25 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 4 92 26 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 3 93 27 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 2 94 28 Gekozen url: http://www.kbsdevlieger1.nl/ouders/downloads.html/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
#  - 1 95 29 Gekozen url: http://www.kbsdevlieger1.nl/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\'/\'/ouders/downloads.html\' "<span class="\'s5_sub_a_span\'" onclick="\'window.document.location.href=&quot;/ouders/downloads.html&quot;\'">downloads</span>"
# 14:13:41 instelling:  07QB 11454
#  - 30 1 0 Gekozen url: http://www.de-expeditiedidam.nl "start"
# 14:13:43 instelling:  02VO00 3224
#  - 30 1 0 Gekozen url: http://www.gymnasiumnovum.nl "start"
# 14:13:44 instelling:  12PC00 18815
#  - 30 1 0 Gekozen url: http://www.bs-deregenboog.nl "start"
#  - 29 148 1 Gekozen url: http://www.bs-deregenboog.nl/pagina/276354/Schoolgids+2018+-+2019 "schoolgids 2018 - 2019"
#  - 28 149 2 Gekozen url: http://www.bs-deregenboog.nl/bestanden/484989/Schoolgids-2018-2019.pdf "schoolgids 2018-2019"
# downloaden: schoolgids_2018_12PC00.pdf u_link
#  - 27 146 3 Gekozen url: http://www.bs-deregenboog.nl/file_popup.php?id=295147 "hier downloaden"
#  - 26 145 4 Gekozen url: http://www.adobe.com/ " "
#  - 25 218 5 Gekozen url: http://www.adobe.com/africa/ " "
#  - 24 333 6 Gekozen url: https://helpx.adobe.com/africa/download-install.html?promoid=2K4PCJ2R&amp;mv=other "download & install"
#  - 23 459 7 Gekozen url: https://forums.adobe.com/community/download_install_setup "adobe forums | downloading, installing, setting up"
#  - 22 557 8 Gekozen url: https://helpx.adobe.com/africa/download-install/using/download-creative-cloud-apps.html "download your creative cloud apps (first-time users)"
#  - 21 581 9 Gekozen url: https://helpx.adobe.com/africa/creative-cloud/help/download-install-new-computer.html "download and install creative cloud apps on a new computer (existing users)"
#  - 20 585 10 Gekozen url: https://helpx.adobe.com/africa/creative-cloud/help/download-install-trial.html "download and install a creative cloud trial"
#  - 19 599 11 Gekozen url: https://helpx.adobe.com/africa/creative-cloud/kb/troubleshoot-download-install.html "troubleshoot creative cloud desktop app download and install issues"
#  - 18 634 12 Gekozen url: https://helpx.adobe.com/africa/creative-cloud/kb/troubleshoot-download-install-log-files.html "troubleshoot download and install errors"
#  - 17 647 13 Gekozen url: https://helpx.adobe.com/africa/creative-cloud/kb/download-update-errors.html "error downloading or updating creative cloud apps"
#  - 16 666 14 Gekozen url: https://helpx.adobe.com/africa/stock/kb/unable-to-download-adobe-stock-images.html "unable to download adobe stock images"
#  - 15 671 15 Gekozen url: https://forums.adobe.com/community/download_install_setup/creative_cloud_faq "community | creative cloud download & install"
#  - 14 692 16 Gekozen url: https://helpx.adobe.com/africa/acrobat/kb/download-install-acrobat-subscription.html "download and install acrobat dc subscription"
#  - 13 699 17 Gekozen url: https://helpx.adobe.com/africa/acrobat/kb/acrobat-downloads.html "download and install acrobat products"
#  - 12 708 18 Gekozen url: https://helpx.adobe.com/africa/acrobat/kb/acrobat-2017-downloads.html "download and install acrobat 2017"
#  - 11 710 19 Gekozen url: https://helpx.adobe.com/africa/x-productkb/policy-pricing/cs6-product-downloads.html "download creative suite 6 applications"
#  - 10 734 20 Gekozen url: https://helpx.adobe.com/africa/creative-cloud/help/download-install-single-app-Lightroom-6.html "download and install lightroom 6 (single app license)"
#  - 9 742 21 Gekozen url: https://helpx.adobe.com/africa/creative-suite/kb/download-install-trials.html "download and install non\xe2\x80\x93creative cloud trial apps"
#  - 8 765 22 Gekozen url: https://helpx.adobe.com/africa/x-productkb/policy-pricing/ADA_discontinued.html "remove the discontinued adobe download assistant"
#  - 7 768 23 Gekozen url: https://helpx.adobe.com/africa/x-productkb/global/troubleshoot-download-problems.html "troubleshoot creative suite download problems"
#  - 6 786 24 Gekozen url: https://helpx.adobe.com/africa/creative-suite/kb/start-installer-downloading.html "start the installer after downloading | acrobat x, cs5.5 and earlier"
#  - 5 785 25 Gekozen url: http://www.adobe.com/africa/downloads/other-downloads.html "other product downloads"
#  - 4 804 26 Gekozen url: https://get.adobe.com/africa/flashplayer "download and install flash player"
#  - 3 803 27 Gekozen url: https://get.adobe.com/africa/air/ "download and install adobe air"
#  - 2 810 28 Gekozen url: http://www.adobe.com/africa/devnet/air/air-sdk-download.html "download and install adobe air sdk"
#  - 1 817 29 Gekozen url: https://get.adobe.com/africa/shockwave/ "download and install shockwave player"
# 14:15:07 instelling:  29XE00 39782
#  - 30 1 0 Gekozen url: http://www.obsatlantis.nl "start"
#  - 29 48 1 Gekozen url: https://obsatlantis.nl/onderwijs/schoolgids/ "schoolgids"
#  - 28 52 2 Gekozen url: https://obsatlantis.nl/wp-content/uploads/Schoolgids-Atlantis-2017-2018.pdf "schoolgids atlantis 2017-2018"
# downloaden: schoolgids_2017_29XE00.pdf u_link
#  - 27 51 3 Gekozen url: http://www.linkedin.com/shareArticle?mini=true&amp;url=https://obsatlantis.nl/onderwijs/schoolgids/ "start"
# 14:15:15 instelling:  20EM00 30780
#  - 30 1 0 Gekozen url: http://www.werkmancollege.nl "start"
#  - 29 50 1 Gekozen url: http://www.werkmancollege.nl/ "<div>organisatie</div>"
#  - 28 50 2 Gekozen url: http://www.werkmancollege.nl/organisatie/index.html "<div>organisatie</div>"
#  - 27 50 3 Gekozen url: http://www.werkmancollege.nl/organisatie/index.html/ "<div>organisatie</div>"
#  - 26 49 4 Gekozen url: http://www.werkmancollege.nl/kwaliteit/bovenschoolsevoorzieningen.html "bovenschoolse voorzieningen"
#  - 25 50 5 Gekozen url: http://www.werkmancollege.nl/kwaliteit/bovenschoolsevoorzieningen.html/ "<div>organisatie</div>"
#  - 24 48 6 Gekozen url: http://www.alleinternetbrowsers.nl "vo"
#  - 23 73 7 Gekozen url: http://www.mozilla.org/nl/firefox/new/ "download firefox"
#  - 22 112 8 Gekozen url: https://www.google.com/intl/nl/chrome/ "download chrome"
#  - 21 146 9 Gekozen url: https://support.apple.com/downloads/safari "download safari"
#  - 20 153 10 Gekozen url: https://www.microsoft.com/nl-nl/windows/microsoft-edge "download edge"
#  - 19 311 11 Gekozen url: https://www.microsoft.com/nl-nl/windows/s-mode "documenten"
#  - 18 318 12 Gekozen url: https://www.microsoft.com/nl-nl/store/b/aboutwarranties?icid=GlobalFooterNav "documenten"
#  - 17 344 13 Gekozen url: https://www.microsoft.com/nl-nl/store/b/terms-of-sale "documenten"
#  - 16 360 14 Gekozen url: https://go.microsoft.com/fwlink/?LinkId=521839 "documenten"
#  - 15 466 15 Gekozen url: https://www.microsoft.com/en-ie/eucompliancedoc/default.aspx "documenten"
#  - 14 1546 16 Gekozen url: https://choice.microsoft.com/ "documenten"
#  - 13 1555 17 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 12 1555 18 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 11 1555 19 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 10 1555 20 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 9 1555 21 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 8 1555 22 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 7 1555 23 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 6 1555 24 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 5 1555 25 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 4 1555 26 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 3 1555 27 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 2 1555 28 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
#  - 1 1555 29 Gekozen url: https://choice.microsoft.com/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show()/javascript:MeePortal.Feedback.control.show() "documenten"
# 14:16:36 instelling:  82616 48700
#  - 30 1 0 Gekozen url: http://info.pbs-bodegraven.nl "start"
# 14:16:37 instelling:  70644 47764
#  - 30 1 0 Gekozen url: http://www.paulusschool-giesbeek.nl "start"
#  - 29 64 1 Gekozen url: http://www.paulusschool-giesbeek.nl/school/schoolgids.html "schoolgids"
#  - 28 68 2 Gekozen url: http://www.paulusschool-giesbeek.nl/school/schoolgids.html/../school/schoolgids.html "schoolgids"
#  - 27 67 3 Gekozen url: http://www.paulusschool-giesbeek.nl/school/schoolgids.html/ "/school/schoolgids.html/#"
# 14:16:42 instelling:  13UO00 20686
#  - 30 1 0 Gekozen url: http://www.obs-noorderbreedte.nl "start"
#  - 29 69 1 Gekozen url: http://obs-noorderbreedte.nl/onzeschool/schoolgids.html "schoolgids \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t"
#  - 28 71 2 Gekozen url: http://www.obs-noorderbreedte.nl/onzeschool/schoolgids.html "schoolgids"
#  - 27 72 3 Gekozen url: https://noorderbreedte.mijnschool.nl/onzeschool/schoolgids.html "schoolgids"
#  - 26 72 4 Gekozen url: http://obs-noorderbreedte.nl/contentfiles/noorderbreedte/Document/64649/64648950.pdf "schoolgids"
# pas de functie bedenk_naam aan omdat geen jaar bepaald kon worden
# downloaden: schoolgids_0000_13UO00.pdf u_link
#  - 25 72 5 Gekozen url: http://www.obs-noorderbreedte.nl/contentfiles/noorderbreedte/Document/64649/64648950.pdf "schoolgids"
# pas de functie bedenk_naam aan omdat geen jaar bepaald kon worden
# downloaden: schoolgids_0000_13UO00.pdf u_link
#  - 24 72 6 Gekozen url: https://noorderbreedte.mijnschool.nl/contentfiles/noorderbreedte/Document/64649/64648950.pdf "schoolgids"
# pas de functie bedenk_naam aan omdat geen jaar bepaald kon worden
# downloaden: schoolgids_0000_13UO00.pdf u_link
#  - 23 70 7 Gekozen url: http://obs-noorderbreedte.nl/onzeschool/schoolplan.html "schoolplan \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t"
#  - 22 70 8 Gekozen url: http://www.obs-noorderbreedte.nl/onzeschool/schoolplan.html "schoolplan"
#  - 21 71 9 Gekozen url: https://noorderbreedte.mijnschool.nl/onzeschool/schoolplan.html "schoolplan"
#  - 20 71 10 Gekozen url: http://obs-noorderbreedte.nl/contentfiles/noorderbreedte/Document/700/699911.pdf "schoolplan"
# pas de functie bedenk_naam aan omdat geen jaar bepaald kon worden
# downloaden: schoolplan_0000_13UO00.pdf u_link
#  - 19 71 11 Gekozen url: http://www.obs-noorderbreedte.nl/contentfiles/noorderbreedte/Document/700/699911.pdf "schoolplan"
# pas de functie bedenk_naam aan omdat geen jaar bepaald kon worden
# downloaden: schoolplan_0000_13UO00.pdf u_link
#  - 18 71 12 Gekozen url: https://noorderbreedte.mijnschool.nl/contentfiles/noorderbreedte/Document/700/699911.pdf "schoolplan"
# pas de functie bedenk_naam aan omdat geen jaar bepaald kon worden
# downloaden: schoolplan_0000_13UO00.pdf u_link
#  - 17 69 13 Gekozen url: http://obs-noorderbreedte.nl/onzeschool/index.html "onze school "
#  - 16 66 14 Gekozen url: https://noorderbreedte.mijnschool.nl/contentfiles/noorderbreedte/Document/66036/66036121.pdf "<i class="fa fa-angle-right"></i>"
#  - 15 66 15 Gekozen url: https://noorderbreedte.mijnschool.nl/contentfiles/noorderbreedte/Document/65388/65388238.pdf "<i class="fa fa-angle-right"></i>"
#  - 14 63 16 Gekozen url: http://obs-noorderbreedte.nl/onzeschool/schoolondersteuningsprofiel.html "schoolondersteuningsprofiel \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t"
#  - 13 62 17 Gekozen url: http://obs-noorderbreedte.nl/onzeschool/schoolregels.html "schoolregels \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t"
#  - 12 62 18 Gekozen url: http://obs-noorderbreedte.nl/ouders/schooltijden.html "schooltijden \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t"
#  - 11 62 19 Gekozen url: https://noorderbreedte.mijnschool.nl/mijnschool/index.html "mijn school \n\t\t\t\t\t\t\t\t\t\t\t\t"
#  - 10 67 20 Gekozen url: https://noorderbreedte.mijnschool.nl/mijnschool/login/gebruikersnaamvergeten.html " "
#  - 9 65 21 Gekozen url: http://obs-noorderbreedte.nl/index.html "noorderbreedte | openbare basisschool"
#  - 8 66 22 Gekozen url: http://www.obs-noorderbreedte.nl/onzeschool/schoolondersteuningsprofiel.html "schoolondersteuningsprofiel"
#  - 7 68 23 Gekozen url: https://noorderbreedte.mijnschool.nl/onzeschool/schoolondersteuningsprofiel.html "schoolondersteuningsprofiel"
#  - 6 68 24 Gekozen url: https://noorderbreedte.mijnschool.nl/contentfiles/noorderbreedte/Document/35249/35249426.pdf "schoolondersteuningsprofiel"
# pas de functie bedenk_naam aan omdat geen jaar bepaald kon worden
# downloaden: schoolondersteuningsprofiel_0000_13UO00.pdf u_link
#  - 5 67 25 Gekozen url: http://www.obs-noorderbreedte.nl/ouders/schooltijden.html "schooltijden"
#  - 4 66 26 Gekozen url: http://www.obs-noorderbreedte.nl/onzeschool/schoolregels.html "schoolregels"
#  - 3 67 27 Gekozen url: https://noorderbreedte.mijnschool.nl/onzeschool/schoolregels.html "schoolregels"
#  - 2 64 28 Gekozen url: http://obs-noorderbreedte.nl "schoolwebsite "
#  - 1 58 29 Gekozen url: http://obs-noorderbreedte.nl/nieuwsbericht/39440046-uitnodiging.html "ouders"
# 14:17:34 instelling:  17WP 26892
#  - 30 1 0 Gekozen url: http://www.wpkeesboeke.nl "start"
#  - 29 15 1 Gekozen url: http://www.wpkeesboeke.nl/bo "basisonderwijs"
#  - 28 21 2 Gekozen url: http://www.wpkeesboeke.nl/bo/bo "basisonderwijs"
#  - 27 21 3 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo "basisonderwijs"
#  - 26 21 4 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo "basisonderwijs"
#  - 25 21 5 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo "basisonderwijs"
#  - 24 21 6 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 23 21 7 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 22 21 8 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 21 21 9 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 20 21 10 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 19 21 11 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 18 21 12 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 17 21 13 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 16 21 14 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 15 21 15 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 14 21 16 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 13 21 17 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 12 21 18 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 11 21 19 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 10 21 20 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 9 21 21 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 8 21 22 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 7 21 23 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 6 21 24 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 5 21 25 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 4 21 26 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 3 21 27 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 2 21 28 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
#  - 1 21 29 Gekozen url: http://www.wpkeesboeke.nl/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo/bo "basisonderwijs"
# 14:18:10 instelling:  21LV00 32458
#  - 30 1 0 Gekozen url: http://www.triolier-akkoord-po.nl "start"
#  - 29 55 1 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/374761/Schoolgids "schoolgids"
#  - 28 54 2 Gekozen url: http://www.basisonline.nl "school"
#  - 27 154 3 Gekozen url: http://www.basisonline.nl/Privacy-Cookies "school"
#  - 26 160 4 Gekozen url: http://www.basisonline.nl/Privacy-Cookies/ "school"
#  - 25 156 5 Gekozen url: http://www.triolier-akkoord-po.nl/bestanden/481097/Kalender-2018-2019.pdf "schoolkalender 2018-2019"
#  - 24 155 6 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties "schooltijden en vakanties"
#  - 23 159 7 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript: "school"
#  - 22 159 8 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript: "school"
#  - 21 159 9 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript: "school"
#  - 20 159 10 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript: "school"
#  - 19 159 11 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 18 159 12 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 17 159 13 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 16 159 14 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 15 159 15 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 14 159 16 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 13 159 17 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 12 159 18 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 11 159 19 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 10 159 20 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 9 159 21 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 8 159 22 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 7 159 23 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 6 159 24 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 5 159 25 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 4 159 26 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 3 159 27 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 2 159 28 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
#  - 1 159 29 Gekozen url: http://www.triolier-akkoord-po.nl/pagina/398669/Schooltijden+en+vakanties/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript:/javascript: "school"
# 14:18:59 instelling:  17NZ 26392
#  - 30 1 0 Gekozen url: http://www.bs-klimboom.nl "start"
# 14:19:00 instelling:  27067 38816
#  - 30 1 0 Gekozen url: http://www.cbs-derank.nl "start"
# 14:19:01 instelling:  09CJ 13872
#  - 30 1 0 Gekozen url: http://www.demolenvliet.nl "start"
#  - 29 52 1 Gekozen url: http://www.demolenvliet.nl/wordpress/schoolgids-2/hoofdstuk-1-naam/ "schoolgids"
#  - 28 51 2 Gekozen url: http://www.demolenvliet.nl/wordpress/groepen-2/plusklas/ "school"
